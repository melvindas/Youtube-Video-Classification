# %%
import pandas as pd 
df_copy= pd.read_csv('out113311pricely.csv')

# %%
df_copy
# Out:
#       Unnamed: 0         link  \
# 0              0      JLZlCZ0
# 1              1  i9E_Blai8vk
# 2              2   2NQE41J5eM
# 3              3    n79Rv0F48
# 4              4  i5F7Xh9CO8U
# 5              5  f59dDEk57i0
# 6              6  EthqIhPtd2I
# 7              7  RcmrbNRK-jY
# 8              8  kiNyRY5s7n8
# 9              9  SL_YBLWdZb8
# 10            10  CBwKJfrm5-U
# 11            11  kdASyS-74Y8
# 12            12  d8mKGr8Ri-k
# 13            13  XAvUfChp7-Y
# 14            14    x5lQYHfpU
# 15            15  FuDkiZkJQh0
# 16            16  4jjFEPeZkJ0
# 17            17  fxnQ6cWmvQU
# 18            18  ksUfScPINEU
# 19            19  7ByoBJYXU0k
# 20            20  NmyvSWq7l2E
# 21            21  942sCY6d7kU
# 22            22  HX_pbYuBQ3Y
# 23            23  XWnlXivndCA
# 24            24    MV0bL-jdV
# 25            25  7mIzRYh8jGA
# 26            26  KiP6zsrolpU
# 27            27  MGhjvist4gk
# 28            28   6eh9zOqDnQ
# 29            29   YNuv_MKQt4
# ...          ...          ...
# 3171        3318  kfC6MdwLWeY
# 3172        3319   f2O6mQkFii
# 3173        3320  d_k2LqIxOaY
# 3174        3321  BPNTC7uZYrI
# 3175        3322  Mc-v9NPveU4
# 3176        3323   V6EpIABAKK
# 3177        3324   Kgl5-lkT8U
# 3178        3325  Lrle0x_DHBM
# 3179        3326  HdZ9weP5i68
# 3180        3327   xo1VInw-SK
# 3181        3328  UEHwO_UEp7A
# 3182        3329   IfFOE7UnSE
# 3183        3330  JVjTYtLLC40
# 3184        3331      2YTvzHU
# 3185        3332  5pflmgMiyLY
# 3186        3333   ZSMaCs8mQl
# 3187        3334  M3yjtCqomo8
# 3188        3335  rKhfFBbVtFg
# 3189        3336  jMETcglizsM
# 3190        3337  iH97xsI9zXg
# 3191        3338  jqPVlp5OW0Q
# 3192        3340  JL6mXBGYB8g
# 3193        3342    PSdz8YsQ1
# 3194        3343   IeyLyQ9ZMM
# 3195        3344  OrCUb2NYSkE
# 3196        3345     loSA2KMI
# 3197        3346  Blz-npEbOHA
# 3198        3347  C-erWXrMv68
# 3199        3348    4cu4Dwm03
# 3200        3349   C8k-lrJrld
#
#                                                   title  \
# 0     Ep 1| Travelling through North East India | Of...
# 1         Welcome to Bali | Travel Vlog | Priscilla Lee
# 2       How do I travel so much ! How do I earn money!!
# 3     Backpacking In Meghalaya | NorthEast India Tri...
# 4           EXPLORING VARANASI | Benaras Travel Vlog #1
# 5                    Exploring Bhutan - The Travel Vlog
# 6                        TRAVEL VLOG: SANTORINI, GREECE
# 7        200 Days - A Trip Around the World Travel Film
# 8     How to Start a Travel Blog [2019] Travel Blogg...
# 9     Welcome to Peru! | Best Essential Tips & Trave...
# 10               Bali Travel Guide - How to travel Bali
# 11    Europe trip Day 0 | Vlog in hindi 2018 blog to...
# 12    Ep2 | Travelling through North East India |Off...
# 13    Camping in Northeast India | Ziro Vlog # 1 | V...
# 14    Who Am I? Life after quitting my job! My educa...
# 15    TRAVEL VLOG: an Italian summer. | Verona, Crem...
# 3196  Presenting DHRUVTARA (Dhoop Ki Zubaan) Full Vi...  Art and Music
# 3197  Playlist Best of / Lo mejor de Gloria Estefan:...  Art and Music
# 3198                    The owner of the song is Hasbro  Art and Music
# 3199                                     Ich liebe dich  Art and Music
# 3200  The Brain with David Eagleman - What Is Realit...  Art and Music
#
# [3201 rows x 5 columns]

# %%
df_link = pd.DataFrame(columns = ["link"])        

df_title = pd.DataFrame(columns = ["title"])        

df_description = pd.DataFrame(columns = ["description"])        

df_category = pd.DataFrame(columns = ["category"])        

df_link['link'] = df_copy['link'] 

df_title ['title']= df_copy['title'] 

df_description['description'] = df_copy['description'] 

df_category['category'] = df_copy['category']

# %%
df_description['description']
# Out:
# 0       The journey to Arunachal, North East India beg...
# 1       I had the chance to fly out to Bali with my wh...
# 2       SUBSCRIBE - https://goo.gl/dEtSMJ (‘MountainTr...
# 3       In this video I explored North East India, sta...
# 4       Spent an incredible week exploring the beautif...
# 5       so finally the vlog is up . this is just a bri...
# 6       Thank you so much for watching! I hope you fou...
# 7       My wife and I traveled to 17 countries in 200 ...
# 8       Create a Travel Blog Website for Just $3.95 + ...
# 9       Welcome to Peru! This essential travel guide w...
# 10      Check out my Bali Travel Guide blog post for m...
# 11      Friends, many of us have already visited a lot...
# 12      In this video we enter into the mystical Mechu...
# 13      Here's presenting a vlog 1 from Ziro Festival ...
# 14      Hey Guys! Thank you so much for sending in all...
# 15      Thank you so much for watching! This summer wa...
# 16      XO LIKE AND SUBSCRIBE IF THIS WAS USEFUL XO\r\...
# 17      Hey Internet!\r\nThank you for watching this v...
# 18      You may want to grab a snack for this one... W...
# 19      Travel blogger, Nikki Vargas, of The Pin the M...
# 20      🧡INSTAGRAM: https://www.instagram.com/cocolili...
# 21      Hello, and welcome to TopX, where we count dow...
# 22      Seeing new places, meeting different people, t...
# 23      #travel #blog #rochdale\r\n\r\nAfter having a ...
# 24      I partnered with Visa and traveled to Thailand...
# 25      Subscribe now: https://goo.gl/6zXZGK\r\nWatch ...
# 26      How To Start A Travel Blog | Travel Blogging 1...
# 27      With your trip just ahead, it's time to learn ...
# 28      Top 10 Travel Vloggers Subscribe: http://bit.l...
# 29      #WordPress #Tutorials\r\nIn this video tutoria...
#                               ...
# 3171    Hey Guys!\r\nHow to be ART HOE // (Aesthetic)\...
# 3172    View full lesson: http://ed.ted.com/lessons/ho...
# 3173    The official New Years Eve aftermovie of Coone...
# 3174    The third single to be taken from Coldplay's a...
# 3175    Here's the official video for "Woke Up Late ft...
# 3176    Lyrical Lemonade Presents:\r\n\r\nBlueface - T...
# 3177    “Best Part, a Visual”\r\n\r\nDirected by Keava...
# 3178    The Maurice White story is a MUST read for any...
# 3179    Lyrics:\r\nAAAAAAAAAAAAAAAAAAAAAAAAAAAHHHHHHHH...
# 3180    Rachel Platten - Fight Song Fight Song EP is n...
# 3181    This video was taken from “Beth Hart & Joe Bon...
# 3182    ArtHub creates single network of Artists-Organ...
# 3183    Follow me on  Instagram - https://www.instagra...
# 3184    How to do alaap in singing ....\r\nHow to sing...
# 3185     Stellamara - Prituri Se Planinata [NIT GRIT RMX]
# 3186    https://youtu.be/ZSMaCs8mQls\r\n"50 Greatest P...
# 3187    BabyFirst brings you a 20 Minute Colors Compil...
# 3188    SUPPORT THE NERDWRITER ON PATREON: http://www....
# 3189    New Single KARTINI - LUKA \r\n#Music SUBSCRIBE...
# 3190    Presenting KORI PUKAAR Full Video song from ZU...
# 3191    ▶︎ DOWNLOAD: https://DirtyWorkz.lnk.to/HereICo...
# 3192    #SagaMusic presents soothing heart touching Pu...
# 3193    #Title Song :-  Dhakkad Chhori\r\n#Singer :- S...
# 3194    Presenting AJJ SAANU O MILEYA (The Anthem of D...
# 3195    After freestyling onstage for Kendrick during ...
# 3196    Presenting DHRUVTARA (Dhoop Ki Zubaan) Full Vi...
# 3197    Playlist Best of / Lo mejor de Gloria Estefan:...
# 3198                      The owner of the song is Hasbro
# 3199                                       Ich liebe dich
# 3200    The Brain with David Eagleman - What Is Realit...
# Name: description, Length: 3201, dtype: object

# %%
import re 

import nltk 

nltk.download('stopwords') 

from nltk.corpus import stopwords 

from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\melvi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []        

for i in range(0, 3201):         

    review = re.sub('[^a-zA-Z]', ' ', df_title['title'][i])            

    review = review.lower()            

    review = review.split()            

    ps = PorterStemmer()            

    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]            

    review = ' '.join(review)            

    corpus.append(review)

# %%
corpus1 = [] 

for i in range(0,3201):          

    review = re.sub('[^a-zA-Z]', ' ', df_description['description'][i])            

    review = review.lower()            

    review = review.split()            

    ps = PorterStemmer()            

    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]            

    review = ' '.join(review)            

    corpus1.append(review)

# %%
dftitle = pd.DataFrame({'title':corpus})

dfdescription = pd.DataFrame({'description':corpus1})

# %%
from sklearn.preprocessing import LabelEncoder

dfcategory = df_category.apply(LabelEncoder().fit_transform)

# %%
df_new = pd.concat([df_link, dftitle, dfdescription, dfcategory], axis=1, join_axes = [df_link.index])

# %%
from skle
arn.feature_extraction.text import CountVectorizer   

cv = CountVectorizer(max_features = 1500) 

X = cv.fit_transform(corpus, corpus1).toarray() 

y = df_new.iloc[:, 3].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 1000, criterion = 'entropy')

classifier.fit(X_train, y_train)
# Out:
# C:\Users\melvi\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = classifier.predict(X_test)

classifier.score(X_test, y_test)
# Out:
# 0.9719188767550702

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97       134
#           1       0.97      0.97      0.97        65
#           2       0.97      1.00      0.98        92
#           3       1.00      0.92      0.96       106
#           4       0.97      0.98      0.98       165
#           5       0.99      0.96      0.97        79
#
# avg / total       0.97      0.97      0.97       641

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(C= 0.1, penalty= 'l1')
clf.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = clf.predict(X_test)

clf.score(X_test, y_test)

print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      0.89      0.94       134
#           1       0.97      0.94      0.95        65
#           2       0.97      0.92      0.94        92
#           3       0.74      1.00      0.85       106
#           4       0.99      0.93      0.96       165
#           5       1.00      0.91      0.95        79
#
# avg / total       0.95      0.93      0.93       641

# %%
X_train.shape
# Out:
# (2560, 1500)

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout


model = Sequential()
model.add(Dense(512, input_shape=(1500,)))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(6))
model.add(Activation('softmax'))
model.summary()
 
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam', metrics=['acc',f1_m,precision_m, recall_m])
 
history = model.fit(X_train, y_train,
                    batch_size=100,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1)

# evaluate the model
loss, accuracy, f1_score, precision, recall = model.evaluate(X_test, y_test, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_53 (Dense)             (None, 512)               768512
# _________________________________________________________________
# activation_52 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_54 (Dense)             (None, 512)               262656
# _________________________________________________________________
# activation_53 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_55 (Dense)             (None, 6)                 3078
# _________________________________________________________________
# activation_54 (Activation)   (None, 6)                 0
# =================================================================
# Total params: 1,034,246
# Trainable params: 1,034,246
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2304 samples, validate on 256 samples
# Epoch 1/30
# 2304/2304 [==============================] - 2s 784us/step - loss: 1.1161 - acc: 0.7821 - f1_m: 3.6096 - precision_m: 888888892.2775 - recall_m: 2.0731 - val_loss: 0.2785 - val_acc: 0.9609 - val_f1_m: 1.1043 - val_precision_m: 1.0350 - val_recall_m: 1.1844
# Epoch 2/30
# 2304/2304 [==============================] - 1s 316us/step - loss: 0.1538 - acc: 0.9748 - f1_m: 1.0270 - precision_m: 0.9660 - recall_m: 1.0981 - val_loss: 0.0959 - val_acc: 0.9648 - val_f1_m: 0.9590 - val_precision_m: 0.8705 - val_recall_m: 1.0684
# Epoch 3/30
# 2304/2304 [==============================] - 1s 304us/step - loss: 0.0524 - acc: 0.9891 - f1_m: 0.9370 - precision_m: 0.8629 - recall_m: 1.0262 - val_loss: 0.0944 - val_acc: 0.9648 - val_f1_m: 0.9369 - val_precision_m: 0.8506 - val_recall_m: 1.0436
# Epoch 4/30
# 2304/2304 [==============================] - 1s 318us/step - loss: 0.0277 - acc: 0.9944 - f1_m: 0.9198 - precision_m: 0.8436 - recall_m: 1.0122 - val_loss: 0.0947 - val_acc: 0.9688 - val_f1_m: 0.9307 - val_precision_m: 0.8402 - val_recall_m: 1.0439
# Epoch 5/30
# 2304/2304 [==============================] - 1s 279us/step - loss: 0.0191 - acc: 0.9948 - f1_m: 0.9159 - precision_m: 0.8389 - recall_m: 1.0095 - val_loss: 0.0957 - val_acc: 0.9648 - val_f1_m: 0.9443 - val_precision_m: 0.8526 - val_recall_m: 1.0593
# Epoch 6/30
# 2304/2304 [==============================] - 1s 277us/step - loss: 0.0116 - acc: 0.9965 - f1_m: 0.9124 - precision_m: 0.8352 - recall_m: 1.0061 - val_loss: 0.0953 - val_acc: 0.9648 - val_f1_m: 0.9202 - val_precision_m: 0.8292 - val_recall_m: 1.0345
# Epoch 7/30
# 2304/2304 [==============================] - 1s 266us/step - loss: 0.0130 - acc: 0.9952 - f1_m: 0.9113 - precision_m: 0.8342 - recall_m: 1.0048 - val_loss: 0.0987 - val_acc: 0.9727 - val_f1_m: 0.9488 - val_precision_m: 0.8565 - val_recall_m: 1.0646
# Epoch 8/30
# 2304/2304 [==============================] - 1s 282us/step - loss: 0.0098 - acc: 0.9961 - f1_m: 0.9121 - precision_m: 0.8352 - recall_m: 1.0057 - val_loss: 0.0983 - val_acc: 0.9688 - val_f1_m: 0.9333 - val_precision_m: 0.8410 - val_recall_m: 1.0492
# Epoch 9/30
# 2304/2304 [==============================] - 1s 292us/step - loss: 0.0094 - acc: 0.9974 - f1_m: 0.9107 - precision_m: 0.8338 - recall_m: 1.0041 - val_loss: 0.0990 - val_acc: 0.9688 - val_f1_m: 0.9625 - val_precision_m: 0.8687 - val_recall_m: 1.0803
# Epoch 10/30
# 2304/2304 [==============================] - 1s 276us/step - loss: 0.0093 - acc: 0.9974 - f1_m: 0.9107 - precision_m: 0.8338 - recall_m: 1.0041 - val_loss: 0.1033 - val_acc: 0.9727 - val_f1_m: 0.9536 - val_precision_m: 0.8607 - val_recall_m: 1.0702
# Epoch 11/30
# 2304/2304 [==============================] - 1s 278us/step - loss: 0.0090 - acc: 0.9965 - f1_m: 0.9085 - precision_m: 0.8316 - recall_m: 1.0022 - val_loss: 0.1037 - val_acc: 0.9648 - val_f1_m: 0.9446 - val_precision_m: 0.8527 - val_recall_m: 1.0599
# Epoch 12/30
# 2304/2304 [==============================] - 1s 281us/step - loss: 0.0066 - acc: 0.9970 - f1_m: 0.9096 - precision_m: 0.8323 - recall_m: 1.0037 - val_loss: 0.1048 - val_acc: 0.9648 - val_f1_m: 0.9510 - val_precision_m: 0.8603 - val_recall_m: 1.0646
# Epoch 13/30
# 2304/2304 [==============================] - 1s 289us/step - loss: 0.0074 - acc: 0.9974 - f1_m: 0.9091 - precision_m: 0.8322 - recall_m: 1.0031 - val_loss: 0.1027 - val_acc: 0.9688 - val_f1_m: 0.9290 - val_precision_m: 0.8371 - val_recall_m: 1.0445
# Epoch 14/30
# 2304/2304 [==============================] - 1s 286us/step - loss: 0.0062 - acc: 0.9978 - f1_m: 0.9108 - precision_m: 0.8339 - recall_m: 1.0042 - val_loss: 0.1086 - val_acc: 0.9688 - val_f1_m: 0.9137 - val_precision_m: 0.8220 - val_recall_m: 1.0295
# Epoch 15/30
# 2304/2304 [==============================] - 1s 283us/step - loss: 0.0067 - acc: 0.9983 - f1_m: 0.9078 - precision_m: 0.8306 - recall_m: 1.0021 - val_loss: 0.1121 - val_acc: 0.9727 - val_f1_m: 0.9405 - val_precision_m: 0.8459 - val_recall_m: 1.0599
# Epoch 16/30
# 2304/2304 [==============================] - 1s 295us/step - loss: 0.0052 - acc: 0.9978 - f1_m: 0.9095 - precision_m: 0.8323 - recall_m: 1.0036 - val_loss: 0.1078 - val_acc: 0.9688 - val_f1_m: 0.9137 - val_precision_m: 0.8220 - val_recall_m: 1.0295
# Epoch 17/30
# 2304/2304 [==============================] - 1s 287us/step - loss: 0.0085 - acc: 0.9970 - f1_m: 0.9092 - precision_m: 0.8319 - recall_m: 1.0037 - val_loss: 0.1185 - val_acc: 0.9648 - val_f1_m: 0.9360 - val_precision_m: 0.8421 - val_recall_m: 1.0546
# Epoch 18/30
# 2304/2304 [==============================] - 1s 286us/step - loss: 0.0064 - acc: 0.9970 - f1_m: 0.9085 - precision_m: 0.8307 - recall_m: 1.0031 - val_loss: 0.1161 - val_acc: 0.9688 - val_f1_m: 0.9407 - val_precision_m: 0.8461 - val_recall_m: 1.0602
# Epoch 19/30
# 2304/2304 [==============================] - 1s 287us/step - loss: 0.0101 - acc: 0.9961 - f1_m: 0.9096 - precision_m: 0.8323 - recall_m: 1.0038 - val_loss: 0.1190 - val_acc: 0.9648 - val_f1_m: 0.9272 - val_precision_m: 0.8339 - val_recall_m: 1.0451
# Epoch 20/30
# 2304/2304 [==============================] - 1s 284us/step - loss: 0.0061 - acc: 0.9978 - f1_m: 0.9086 - precision_m: 0.8314 - recall_m: 1.0026 - val_loss: 0.1126 - val_acc: 0.9727 - val_f1_m: 0.9269 - val_precision_m: 0.8339 - val_recall_m: 1.0445
# Epoch 21/30
# 2304/2304 [==============================] - 1s 287us/step - loss: 0.0075 - acc: 0.9970 - f1_m: 0.9100 - precision_m: 0.8330 - recall_m: 1.0036 - val_loss: 0.1184 - val_acc: 0.9688 - val_f1_m: 0.9490 - val_precision_m: 0.8566 - val_recall_m: 1.0649
# Epoch 22/30
# 2304/2304 [==============================] - 1s 281us/step - loss: 0.0067 - acc: 0.9965 - f1_m: 0.9108 - precision_m: 0.8336 - recall_m: 1.0047 - val_loss: 0.1259 - val_acc: 0.9688 - val_f1_m: 0.9275 - val_precision_m: 0.8313 - val_recall_m: 1.0499
# Epoch 23/30
# 2304/2304 [==============================] - 1s 288us/step - loss: 0.0072 - acc: 0.9970 - f1_m: 0.9079 - precision_m: 0.8306 - recall_m: 1.0025 - val_loss: 0.1230 - val_acc: 0.9727 - val_f1_m: 0.9382 - val_precision_m: 0.8456 - val_recall_m: 1.0549
# Epoch 24/30
# 2304/2304 [==============================] - 1s 305us/step - loss: 0.0085 - acc: 0.9961 - f1_m: 0.9094 - precision_m: 0.8318 - recall_m: 1.0038 - val_loss: 0.1181 - val_acc: 0.9688 - val_f1_m: 0.9228 - val_precision_m: 0.8300 - val_recall_m: 1.0401
# Epoch 25/30
# 2304/2304 [==============================] - 1s 294us/step - loss: 0.0086 - acc: 0.9965 - f1_m: 0.9093 - precision_m: 0.8322 - recall_m: 1.0032 - val_loss: 0.1214 - val_acc: 0.9727 - val_f1_m: 0.9275 - val_precision_m: 0.8340 - val_recall_m: 1.0458
# Epoch 26/30
# 2304/2304 [==============================] - 1s 282us/step - loss: 0.0066 - acc: 0.9970 - f1_m: 0.9088 - precision_m: 0.8315 - recall_m: 1.0031 - val_loss: 0.1274 - val_acc: 0.9688 - val_f1_m: 0.9381 - val_precision_m: 0.8456 - val_recall_m: 1.0546
# Epoch 27/30
# 2304/2304 [==============================] - 1s 285us/step - loss: 0.0064 - acc: 0.9965 - f1_m: 0.9081 - precision_m: 0.8310 - recall_m: 1.0020 - val_loss: 0.1299 - val_acc: 0.9688 - val_f1_m: 0.9297 - val_precision_m: 0.8346 - val_recall_m: 1.0499
# Epoch 28/30
# 2304/2304 [==============================] - 1s 276us/step - loss: 0.0068 - acc: 0.9961 - f1_m: 0.9092 - precision_m: 0.8318 - recall_m: 1.0032 - val_loss: 0.1299 - val_acc: 0.9727 - val_f1_m: 0.9318 - val_precision_m: 0.8381 - val_recall_m: 1.0502
# Epoch 29/30
# 2304/2304 [==============================] - 1s 286us/step - loss: 0.0088 - acc: 0.9957 - f1_m: 0.9092 - precision_m: 0.8322 - recall_m: 1.0030 - val_loss: 0.1281 - val_acc: 0.9727 - val_f1_m: 0.9425 - val_precision_m: 0.8493 - val_recall_m: 1.0602
# Epoch 30/30
# 2304/2304 [==============================] - 1s 274us/step - loss: 0.0065 - acc: 0.9970 - f1_m: 0.9084 - precision_m: 0.8314 - recall_m: 1.0027 - val_loss: 0.1299 - val_acc: 0.9688 - val_f1_m: 0.9185 - val_precision_m: 0.8260 - val_recall_m: 1.0354

# %%
loss
# Out:
# 0.06883866020096507

# %%
accuracy
# Out:
# 0.9859594383775351

# %%
f1_score
# Out:
# 0.900216627511517

# %%
precision
# Out:
# 0.8102595049207928

# %%
recall
# Out:
# 0.8233575546713962
